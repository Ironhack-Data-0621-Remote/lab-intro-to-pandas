# %%
# https://github.com/ignaciolorenzo/lab-intro-to-pandas/blob/master/readme.md

# Lab | Customer Analysis Round 1

import pandas as pd
import numpy as np

# %%
# Read the three files into python as dataframes
df1 = pd.read_csv(r"/Users/ignaciolorenzoqueralt/Documents/Ironhack/labs/lab-intro-to-pandas/files_for_lab/csv_files/file1.csv")
df2 = pd.read_csv(r"/Users/ignaciolorenzoqueralt/Documents/Ironhack/labs/lab-intro-to-pandas/files_for_lab/csv_files/file2.csv")
df3 = pd.read_csv(r"/Users/ignaciolorenzoqueralt/Documents/Ironhack/labs/lab-intro-to-pandas/files_for_lab/csv_files/file3.csv")

# %%
# Show the DataFrame's shape.
print("The shape of df1 is ", df1.shape)
print("The shape of df2 is ", df2.shape)
print("The shape of df3 is ", df3.shape)
print("\n")
# Out:
# The shape of df1 is  (4008, 11)
# The shape of df2 is  (996, 11)
# The shape of df3 is  (7070, 11)

# %%
# Standardize header names.
    #first, let's take a look at the headers
df1_columns = []
df2_columns = []
df3_columns = []

for col in df1.columns:
    df1_columns.append(col)
for col in df1.columns:
    df2_columns.append(col)
for col in df1.columns:
    df3_columns.append(col)
    
print(df1.columns,"\n", df1.columns,"\n", df1.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
#  Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
#  Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
    #remove upper case letters
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()

# %%
    #remove blank spaces
df1 = df1.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints',
                             'policy type':'policy_type',
                         'vehicle class':'vehicle_class',
                         'total claim amount':'total_claim_amount',})
df2 = df2.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints',
                             'policy type':'policy_type',
                         'vehicle class':'vehicle_class',
                         'total claim amount':'total_claim_amount',})
df3 = df3.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints',
                             'policy type':'policy_type',
                         'vehicle class':'vehicle_class',
                         'total claim amount':'total_claim_amount',})
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
# Rearrange the columns in the dataframe as needed
# no further rearrangement needed

# %%
# Concatenate the three dataframes
df_list = [df1, df2, df3]
df123 = pd.concat(df_list)
df123
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Which columns are numerical?

num_df123 = df123.select_dtypes(include=np.number)
num_df123.columns
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
# Which columns are categorical?
cat_df123 = df123.select_dtypes(include='category')
cat_df123.columns
# Out:
# Index([], dtype='object')

# %%
# latest step: (to be finished 06 June EOD)

    # Delete the column education and the number of open complaints from the dataframe.
df123.drop(['education', 'number_of_open_complaints'], axis=1)
    
    # Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

df123['customer_lifetime_value'] = df123['customer_lifetime_value']*100
df123['customer_lifetime_value'] = pd.to_numeric(df123['customer_lifetime_value'], errors ='coerce')
df123
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                         NaN      0.0                  94.0
# 2                         NaN  48767.0                 108.0
# ...

# %%
    # Check for duplicate rows in the data and remove if any.
df123 = df123.drop_duplicates()

# %%
    # Filter out the data for customers who have an income of 0 or less.
df123[df123['income']<=0]
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103         NaN      F              Bachelor
# 7061  RX91025         NaN      M  High School or Below
# 7062  AC13887         NaN      M              Bachelor
# 7067  TD14365         NaN      M              Bachelor
# 7069  Y167826         NaN      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                         NaN     0.0                1000.0
# 1                         NaN     0.0                  94.0
# 3                         NaN     0.0                 106.0
# ...
