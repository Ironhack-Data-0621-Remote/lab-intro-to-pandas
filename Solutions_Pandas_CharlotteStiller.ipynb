# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Pandas and alias it to `pd`.

# %%
import pandas as pd

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
#creating + showing a Pandas Series
series = pd.Series(lst)
series
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
#creating + showing Pandas DataFrame
dataframe = pd.DataFrame(b)
dataframe
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 4. Rename the data frame columns based on the names in the list below.

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
#renaming columns + showing new dataframe 

dataframe = dataframe.rename(columns={0: "Score_1", 1: "Score_2", 2: "Score_3", 3: "Score_4", 4: "Score_5" })
dataframe
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 5. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
#creating + showing the new dataframe with Score 1,3,5 columns
dataframe_2 = dataframe.drop(["Score_2", "Score_4"], axis=1)
dataframe_2
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# ### 6. From the original data frame, calculate the average, the median and the maximum Score_3 value.

# %%
#calculating the average, mean and maximum
"average:", dataframe['Score_3'].mean(), "median:", dataframe['Score_3'].median(), "maximum", dataframe['Score_3'].max()
# Out:
# ('average:', 56.95000000000001, 'median:', 53.599999999999994, 'maximum', 96.1)

# %% [markdown]
# ### 7. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
#creating + showing Panda dataframe from dictionary
dataframe_3 = pd.DataFrame(orders)
dataframe_3
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 8. Calculate the total quantity ordered and revenue generated from these orders.

# %%
#calculating total quantity ordered + revenue 
"total quantity:", dataframe_3['Quantity'].sum(), "and revenue", dataframe_3['Revenue'].sum()
# Out:
# ('total quantity:', 2978, 'and revenue', 637.0)

# %% [markdown]
# ## Let's load another dataset for more exercises

# %% [markdown]
# ### 1. Read the three files into python as DataFrames.

# %%
#creating dataframes
df1 = pd.read_excel('file1.xlsx')
df2 = pd.read_excel('file2.xlsx')
df3 = pd.read_excel('file3.xlsx')

# %% [markdown]
# Let's evaluate the three datasets by looking at the `head` function.

# %%
#using the head function
df1.head(), df2.head(), df3.head()
# Out:
# (  Customer          ST GENDER             Education Customer Lifetime Value  \
#  0  RB50392  Washington    NaN                Master                     NaN
#  1  QZ44356     Arizona      F              Bachelor              697953.59%
#  2  AI49188      Nevada      F              Bachelor             1288743.17%
#  3  WW63253  California      M              Bachelor              764586.18%
#  4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
#  0       0                  1000                    1/0/00   Personal Auto
#  1       0                    94                    1/0/00   Personal Auto
#  2   48767                   108                    1/0/00   Personal Auto
#  3       0                   106                    1/0/00  Corporate Auto
#  4   36357                    68                    1/0/00   Personal Auto
#
#     Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# ### 2. Show the shape of the DataFrames.

# %%
#showing the shape
df1.shape, df2.shape, df3.shape
# Out:
# ((1071, 11), (996, 11), (7070, 11))

# %% [markdown]
# ### 3. Standardize header names of the datasets.

# %% [markdown]
# Take in count that you have to remove the spaces in the names.
#
# **hint**: you can use a loop to save time here.

# %%
# standardize header names (lower + remove spaces)

df1.columns = df1.columns.str.lower()

df1 = df1.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints', "policy type":"policy_type",
                            "vehicle class" : "vehicle_class", "total claim amount" : "total_claim_amount"  })



df2.columns = df2.columns.str.lower()

df2 = df2.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints', "policy type":"policy_type",
                            "vehicle class" : "vehicle_class", "total claim amount" : "total_claim_amount"  })





df3.columns = df3.columns.str.lower()

df3 = df3.rename(columns={'customer lifetime value':'customer_lifetime_value',
                            'monthly premium auto':'monthly_premium_auto',
                            'number of open complaints':'number_of_open_complaints', "policy type":"policy_type",
                            "vehicle class" : "vehicle_class", "total claim amount" : "total_claim_amount", "state" : "st"  })

# %% [markdown]
# ### 4. Rearrange the columns in the dataframe as needed

# %%
df1 = df1[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
        'income', 'monthly_premium_auto', 'number_of_open_complaints',
        'policy_type', 'total_claim_amount' , 'vehicle_class' ]]

df2 = df2[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
        'income', 'monthly_premium_auto', 'number_of_open_complaints',
        'policy_type', 'total_claim_amount', 'vehicle_class']]


df3 = df3[['customer', 'st', 'gender','education', 'customer_lifetime_value',  
        'income', 'monthly_premium_auto', 'number_of_open_complaints',
        'policy_type', 'total_claim_amount', 'vehicle_class']]

df1.columns , df2.columns, df3.columns
# Out:
# (Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#         'income', 'monthly_premium_auto', 'number_of_open_complaints',
#         'policy_type', 'total_claim_amount', 'vehicle_class'],
#        dtype='object'),
#  Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#         'income', 'monthly_premium_auto', 'number_of_open_complaints',
#         'policy_type', 'total_claim_amount', 'vehicle_class'],
#        dtype='object'),
#  Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#         'income', 'monthly_premium_auto', 'number_of_open_complaints',
#         'policy_type', 'total_claim_amount', 'vehicle_class'],
#        dtype='object'))

# %% [markdown]
# ### 5. Concatenate the three DataFrames

# %%
data = pd.concat([df1, df2, df3])

# %% [markdown]
# ### 6. Which columns are numerical? And categorical?

# %%
data.info()
#numerical are int64 and float64. Categorical are the object ones
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   income                     9137 non-null   int64
#  6   monthly_premium_auto       9137 non-null   int64
#  7   number_of_open_complaints  9137 non-null   object
#  8   policy_type                9137 non-null   object
#  9   total_claim_amount         9137 non-null   float64
#  10  vehicle_class              9137 non-null   object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 856.6+ KB

# %% [markdown]
# ### 7. In a `markdown` cell, explain briefly the meaning of the columns

# %%
#customer = costumer ID 
#st = state 
#gender = gender
#education = education degree
# customer_lifetime_value = value that the customer brings
# income = income of the custimer 
#monthly_premium_auto = with car is this month the premium one? 
#number_of_open_complaints = how much complaints are open
# policy_type = type of the policy (Example: Personal,Corperate)
#vehicle_class  = class of the whicle (Example: Four-Door, SUV)
#total_claim_amount = total claim amount of the customer

# %% [markdown]
# ### 8. Remove the columns `education` and `Number of Open Complaints` from the DataFrame

# %%
#using function drop to remove education and number of open complaints + showing new result
data = data.drop(["education", "number_of_open_complaints"], axis=1)
data
# Out:
#      customer          st gender customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                     NaN       0
# 1     QZ44356     Arizona      F              697953.59%       0
# 2     AI49188      Nevada      F             1288743.17%   48767
# 3     WW63253  California      M              764586.18%       0
# 4     GA49547  Washington      M              536307.65%   36357
# ...       ...         ...    ...                     ...     ...
# 7065  LA72316  California      M                   23406   71941
# 7066  PK87824  California      F                 3096.51   21604
# 7067  TD14365  California      M                 8163.89       0
# 7068  UP19263  California      M                 7524.44   21941
# 7069  Y167826  California      M                 2611.84       0
#
#       monthly_premium_auto     policy_type  total_claim_amount  vehicle_class
# 0                     1000   Personal Auto            2.704934  Four-Door Car
# ...

# %% [markdown]
# ### 9. Correct the values in the column `Customer Lifetime Value`. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
#first step: replace % 
data["customer_lifetime_value"] = data["customer_lifetime_value"].str.replace("%", "")
#second step: chang into a numerical type
data["customer_lifetime_value"] =  pd.to_numeric(data["customer_lifetime_value"], errors="coerce")
#third step: multiply 
data["customer_lifetime_value"] = 100 * data["customer_lifetime_value"]
# Out:
#      customer          st gender  customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                      NaN       0
# 1     QZ44356     Arizona      F               69795359.0       0
# 2     AI49188      Nevada      F              128874317.0   48767
# 3     WW63253  California      M               76458618.0       0
# 4     GA49547  Washington      M               53630765.0   36357
# ...       ...         ...    ...                      ...     ...
# 7065  LA72316  California      M                      NaN   71941
# 7066  PK87824  California      F                      NaN   21604
# 7067  TD14365  California      M                      NaN       0
# 7068  UP19263  California      M                      NaN   21941
# 7069  Y167826  California      M                      NaN       0
#
#       monthly_premium_auto     policy_type  total_claim_amount  vehicle_class
# 0                     1000   Personal Auto            2.704934  Four-Door Car
# ...

# %% [markdown]
# ### 10. Remove any duplicate rows after check if there are any

# %%
#printing and droping duplicates
print(data[data.duplicated()])
data = data.drop_duplicates()
# Out:
#   customer          st gender  customer_lifetime_value  income  \
# 0  GS98873     Arizona      F                      NaN   16061
# 1  CW49887  California      F                      NaN   79487
# 2  MY31220  California      F                      NaN   54230
#
#    monthly_premium_auto    policy_type  vehicle_class  total_claim_amount  \
# 0                    88  Personal Auto  Four-Door Car               633.6
# 1                   114   Special Auto            SUV               547.2
# 2                   112  Personal Auto   Two-Door Car               537.6
#
#   state gender
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN

# %% [markdown]
# ### 11. Filter out the data for customers who have an income of 0 or less.

# %%
#filtering and showing the result
low_income = data[data["income"]==0]
low_income
# Out:
#      customer          st gender  customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                      NaN       0
# 1     QZ44356     Arizona      F                      NaN       0
# 3     WW63253  California      M                      NaN       0
# 7     CF85061     Arizona      M                      NaN       0
# 10    SX51350  California      M                      NaN       0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103         NaN    NaN              5678.050167       0
# 7061  RX91025         NaN    NaN             19872.262000       0
# 7062  AC13887         NaN    NaN              4628.995325       0
# 7067  TD14365         NaN    NaN              8163.890428       0
# 7069  Y167826         NaN    NaN              2611.836866       0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                     1000   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# ### 1. Count the number of customers by state

# %%
#gouping data by states and count them
data.groupby(['st']).count()
# Out:
#             customer  gender  customer_lifetime_value  income  \
# st
# AZ                74      63                       74      74
# Arizona         1630    1618                      328    1630
# Cali             120     119                      120     120
# California      3032    2995                      488    3032
# Nevada           882     873                      223     882
# Oregon          2601    2557                      623    2601
# WA                30      29                       30      30
# Washington       768     761                      174     768
#
#             monthly_premium_auto  policy_type  total_claim_amount  \
# st
# AZ                            74           74                  74
# Arizona                     1630         1630                1630
# Cali                         120          120                 120
# California                  3032         3032                3032
# ...

# %% [markdown]
# ### 2. What is the average of `claim amount` by gender

# %%
#grouping the gender column + checking out the mean of total claim amount

data.groupby(["gender"]).mean(["total_claim_amount"])
# Out:
#         customer_lifetime_value        income  monthly_premium_auto  \
# gender
# F                  8.013325e+07  38298.674781            111.369079
# Femal              6.216253e+07  41177.764706             81.352941
# M                  7.554568e+07  37385.728938            108.566850
# Male               9.371850e+07  36700.500000            109.125000
# female             6.868491e+07  32436.133333             89.533333
#
#         total_claim_amount
# gender
# F               410.855909
# Femal           366.977404
# M               451.238484
# Male            533.668383
# female          403.774879

# %% [markdown]
# ### 3. Select all the rows where the education level is `Bachelor` or higher

# %%
#education column already deleted during step 8
