# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Pandas and alias it to `pd`.

# %%
import pandas as pd

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
#creating series
series = pd.Series(lst)
#showing series
series
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
#creating DataFrame
dataframe = pd.DataFrame(b)
#showing DataFrame
dataframe
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 4. Rename the data frame columns based on the names in the list below.

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
#renaming columns
dataframe = dataframe.rename(columns={0:'Score_1',
                                        1:'Score_2',
                                        2:'Score_3',
                                        3:'Score_4', 
                                        4:'Score_5'})

#showing dataframe with new column names
dataframe
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 5. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
#creating new dataframe which is dropping columns Score_2 and Score_4
dataframe2 = dataframe.drop(['Score_2', 'Score_4'], axis=1)

#showing new dataframe
dataframe2
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# ### 6. From the original data frame, calculate the average, the median and the maximum Score_3 value.

# %%
#showing general overview of stats of Score_3
dataframe['Score_3'].describe()
# Out:
# count    10.000000
# mean     56.950000
# std      30.168278
# min       0.100000
# 25%      43.450000
# 50%      53.600000
# 75%      80.925000
# max      96.100000
# Name: Score_3, dtype: float64

# %%
#calculating the average
dataframe['Score_3'].mean()
# Out:
# 56.95000000000001

# %%
#calculating the median
dataframe['Score_3'].median()
# Out:
# 53.599999999999994

# %%
#calculating the maximum
dataframe['Score_3'].max()
# Out:
# 96.1

# %% [markdown]
# ### 7. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
#creating new dataframe from a dictionary
dataframe_orders = pd.DataFrame.from_dict(orders)

#showing new dataframe
dataframe_orders
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 8. Calculate the total quantity ordered and revenue generated from these orders.

# %%
#calculating the total quantity ordered
dataframe_orders['Quantity'].sum()
# Out:
# 2978

# %%
#calculating the total revenue of all orders
dataframe_orders['Revenue'].sum()
# Out:
# 637.0

# %% [markdown]
# ## Let's load another dataset for more exercises

# %% [markdown]
# ### 1. Read the three files into python as DataFrames.

# %%
#creating dataframes of all three files
df1 = pd.read_csv('file1.csv')
df2 = pd.read_csv('file2.csv')
df3 = pd.read_csv('file3.csv')

# %% [markdown]
# Let's evaluate the three datasets by looking at the `head` function.

# %%
#looking at dataframe 1
df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
#looking at dataframe 2
df2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
#looking at dataframe 3
df3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %% [markdown]
# ### 2. Show the shape of the DataFrames.

# %%
#showing the shape of df1
df1.shape
# Out:
# (4008, 11)

# %%
#showing the shape of df2
df2.shape
# Out:
# (996, 11)

# %%
#showing the shape of df3
df3.shape
# Out:
# (7070, 11)

# %% [markdown]
# ### 3. Standardize header names of the datasets.

# %% [markdown]
# Take in count that you have to remove the spaces in the names.
#
# **hint**: you can use a loop to save time here.

# %%
#only lowercases for column names in df1
#creating list to store column names with lower cases

cols1 = []

for i in range(len(df1.columns)):
    cols1.append(df1.columns[i].lower())
    
cols1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
#changing column names in df1
df1.columns = cols1
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#removing spaces and adding "_" instead for df1
df1.columns = df1.columns.str.replace(' ', '_')
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#changing column names for df2
df2.columns = df2.columns.str.lower()
df2.columns = df2.columns.str.replace(' ', '_')

df2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
#changing column names for df3
df3.columns = df3.columns.str.lower()
df3.columns = df3.columns.str.replace(' ', '_')

df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %% [markdown]
# ### 4. Rearrange the columns in the dataframe as needed

# %%
#checking column order of df1 to use it for df2 and df3
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
#checking column order + names of df2 
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
#checking column order + names of df3 
df3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
#rearranging columns for df2
df2 = df2[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

#checking new column order of df2
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
#changing name for column 'state' in df3
df3 = df3.rename(columns={'state':'st'})

#checking new column name of df3
df3.columns
# Out:
# Index(['customer', 'st', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
#rearranging columns for df3
df3 = df3[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

#checking new column order of df3
df3.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# ### 5. Concatenate the three DataFrames

# %%
#concatenating all three dataframes
data = pd.concat([df1, df2, df3])
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ### 6. Which columns are numerical? And categorical?

# %%
#checking datatypes of the columns (object = categorical , float64 = numerical)
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %% [markdown]
# ### 7. In a `markdown` cell, explain briefly the meaning of the columns

# %% [markdown]
# # meaning of the columns
#
# |column name               |   meaning of the column                                                 | data type     |
# |--------------------------|-------------------------------------------------------------------------|---------------|
# |customer                  |   customer id                                                           |object
# |st                        |   US state                                                              |object
# |gender                    |   gender                                                                |object
# |education                 |   education                                                             |object
# |income                    |   (yearly?) income                                                      |float64
# |monthly_premium_auto      |    ??                                                                   |float64
# |number_of_open_complaints |   number of open complaints                                             |object
# |policy_type               |   corporate or private car                                              |object
# |vehicle_class             |   type of car                                                           |object
# |total_claim_amount        |   total claim amount (of all complaints - no matter if open or not      |floatf4

# %% [markdown]
# ### 8. Remove the columns `education` and `Number of Open Complaints` from the DataFrame

# %%
#dropping columns from dataframe
data = data.drop(['education', 'number_of_open_complaints'], axis=1)
data
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# ### 9. Correct the values in the column `Customer Lifetime Value`. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
#removing '%' in df1 and df2
df1['customer_lifetime_value'] = df1['customer_lifetime_value'].str.replace('%' , '')

# %%
#changing string to numerical data
df1['customer_lifetime_value'] = pd.to_numeric(df1['customer_lifetime_value']) #no need to add errors='coerce'

#multiplying by 100
df1['customer_lifetime_value'] = 100 * df1['customer_lifetime_value']

df1

#this should have been done with df1 and df2 before concatenating all three dataframes
#looking at the size of the numbers in df3 it seems to make more sense to divide df1 and df2 by 100 (instead of multiplying them by 100)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  69795359.0      0.0                  94.0
# 2                 128874317.0  48767.0                 108.0
# ...

# %% [markdown]
# ### 10. Remove any duplicate rows after check if there are any

# %%
#checking if there are any duplicate rows
data.duplicated().sum()
# Out:
# 2939

# %%
#removing duplicate rows
data = data.drop_duplicates()
data
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# ### 11. Filter out the data for customers who have an income of 0 or less.

# %%
#new dataframe with customers of income <= 0
filtered_income = data[data['income']<=0]
filtered_income
# Out:
#      customer          st gender customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                     NaN     0.0
# 1     QZ44356     Arizona      F              697953.59%     0.0
# 3     WW63253  California      M              764586.18%     0.0
# 7     CF85061     Arizona      M              721610.03%     0.0
# 10    SX51350  California      M              473899.20%     0.0
# ...       ...         ...    ...                     ...     ...
# 7059  WZ45103  California      F             5678.050167     0.0
# 7061  RX91025  California      M               19872.262     0.0
# 7062  AC13887  California      M             4628.995325     0.0
# 7067  TD14365  California      M             8163.890428     0.0
# 7069  Y167826  California      M             2611.836866     0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# ### 1. Count the number of customers by state

# %%
#showing unique values for state column
data['st'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
#showing counts for all unique values
data['st'].value_counts()
# Out:
# California    3030
# Oregon        2601
# Arizona       1629
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: st, dtype: int64

# %%
#showing counts for only one value (combination for California)
#way 1 (California)
california = data['st'].value_counts().California
#way2 (Cali)
cali = data.st.value_counts().Cali

#combination
california_total = california + cali
california_total
# Out:
# 3150

# %%
#showing counts for only one value (combination for Arizona)
#way 1 (Arizona)
arizona = data['st'].value_counts().Arizona
#way2 (AZ)
az = data.st.value_counts().AZ

#combination
arizona_total = arizona + az
arizona_total
# Out:
# 1703

# %%
#showing counts for only one value (combination for Washington)
#way 1 (Washington)
washington = data['st'].value_counts().Washington
#way2 (AZ)
wa = data.st.value_counts().WA

#combination
washington_total = washington + wa
washington_total
# Out:
# 798

# %%
#printing summary of customer count per state
print ('Number of customers in California is: ', california_total)
print ('Number of customers in Arizona is: ', arizona_total)
print ('Number of customers in Washington is: ', washington_total)
print ('Number of customers in Oregon is: ', data.st.value_counts().Oregon)
print ('Number of customers in Nevada is: ', data.st.value_counts().Nevada)
# Out:
# Number of customers in California is:  3150
# Number of customers in Arizona is:  1703
# Number of customers in Washington is:  798
# Number of customers in Oregon is:  2601
# Number of customers in Nevada is:  882

# %% [markdown]
# ### 2. What is the average of `claim amount` by gender

# %%
#show average of total claim amount
data['total_claim_amount'].mean()
# Out:
# 430.48041151773594

# %%
#show average of claim amount by gender
data.groupby(['gender'])['total_claim_amount'].mean()
# Out:
# gender
# F         410.749296
# Femal     366.977404
# M         451.238484
# Male      533.668383
# female    403.774879
# Name: total_claim_amount, dtype: float64

# %% [markdown]
# ### 3. Select all the rows where the education level is `Bachelor` or higher

# %%
#show unique values for education (for df1-3 because eduction is removed in data already)
df1['education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
#show all rows where education level is Bachelor or higher 
#this would work if education hadn't been removed before

data[(data['education']=='Bachelor') | (data['education']=='Bachelors') | (data['education']=='Master') 
     | (data['education']=='Doctor')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\katha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'education'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#show all rows where education level is Bachelor or higher for df1
df1[(df1['education']=='Bachelor') | (df1['education']=='Bachelors') | (df1['education']=='Master') 
     | (df1['education']=='Doctor')]
# Out:
#      customer          st gender education  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN    Master                      NaN      0.0
# 1     QZ44356     Arizona      F  Bachelor               69795359.0      0.0
# 2     AI49188      Nevada      F  Bachelor              128874317.0  48767.0
# 3     WW63253  California      M  Bachelor               76458618.0      0.0
# 5     OC83172      Oregon      F  Bachelor               82562978.0  62902.0
# ...       ...         ...    ...       ...                      ...      ...
# 1064  YT69858  Washington      F  Bachelor               54414201.0  85702.0
# 1065  XD85577        Cali      M  Bachelor               28422669.0  69417.0
# 1066  TM65736      Oregon      M    Master               30595503.0  38644.0
# 1068  GS98873     Arizona      F  Bachelor               32391247.0  16061.0
# 1069  CW49887  California      F    Master               46268011.0  79487.0
#
# ...
