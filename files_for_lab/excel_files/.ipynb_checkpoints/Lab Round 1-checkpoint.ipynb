# %%
import pandas as pd

# %%
#Reading the three files into python as dataframes
df1 = pd.read_excel('file1.xlsx')
df2 = pd.read_excel('file2.xlsx')
df3 = pd.read_excel('file3.xlsx')

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#df1's shape
df1.shape
# Out:
# (1071, 11)

# %%
#df2's shape
df2.shape
# Out:
# (996, 11)

# %%
#df3's shape
df3.shape
# Out:
# (7070, 11)

# %%
#renaming df1 and df2 columns
df1 = df1.rename(columns={'ST':'State',
                          'GENDER':'Gender'})
df1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
df2 = df2.rename(columns={'ST':'State',
                          'GENDER':'Gender'})
df2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
#Rearrange the columns df2 and df3
df2 = df2[['State', 'Gender', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type','Vehicle Class','Total Claim Amount']]
df2
# Out:
#           State Gender Education Customer Lifetime Value  Income  \
# 0       Arizona      F  Bachelor              323912.47%   16061
# 1    California      F    Master              462680.11%   79487
# 2    California      F   College              899704.02%   54230
# 3        Oregon      F   College             2580706.30%   71210
# 4       Arizona      F   College              380812.21%   94903
# ..          ...    ...       ...                     ...     ...
# 991     Arizona      M    Master              847141.75%   63513
# 992     Arizona      F   College              543121.91%   58161
# 993      Nevada      F   College              568964.41%   83640
# 994  California      F    Master              368672.38%       0
# 995  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# ...

# %%
df3 = df3[['State', 'Gender', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type','Vehicle Class','Total Claim Amount']]
df3
# Out:
#            State Gender             Education  Customer Lifetime Value  \
# 0     Washington      M  High School or Below              3479.137523
# 1        Arizona      M                Master              2502.637401
# 2         Nevada      F              Bachelor              3265.156348
# 3     California      F  High School or Below              4455.843406
# 4     California      M  High School or Below              7704.958480
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#       Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
#Concatenate the three dataframes
data = pd.concat([df1, df2, df3])
data
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN  California      M              Bachelor
# 7066      NaN  California      F               College
# 7067      NaN  California      M              Bachelor
# 7068      NaN  California      M               College
# 7069      NaN  California      M               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
#Which columns are numerical?
data._get_numeric_data()
# Out:
#       Income  Monthly Premium Auto  Total Claim Amount
# 0          0                  1000            2.704934
# 1          0                    94         1131.464935
# 2      48767                   108          566.472247
# 3          0                   106          529.881344
# 4      36357                    68           17.269323
# ...      ...                   ...                 ...
# 7065   71941                    73          198.234764
# 7066   21604                    79          379.200000
# 7067       0                    85          790.784983
# 7068   21941                    96          691.200000
# 7069       0                    77          369.600000
#
# [9137 rows x 3 columns]

# %%
#Which columns are categorical?
data.select_dtypes('object')
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN  California      M              Bachelor
# 7066      NaN  California      F               College
# 7067      NaN  California      M              Bachelor
# 7068      NaN  California      M               College
# 7069      NaN  California      M               College
#
#      Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
#Delete the column education and the number of open complaints from the dataframe
data = data.drop(['Education'], axis=1)

# %%
data = data.drop(['Number of Open Complaints'], axis=1)

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Customer Lifetime Value', 'Income',
#        'Monthly Premium Auto', 'Policy Type', 'Vehicle Class',
#        'Total Claim Amount'],
#       dtype='object')

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type
data['Customer Lifetime Value'] = pd.to_numeric(data['Customer Lifetime Value'], errors='coerce')

# %%
data._get_numeric_data()
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                         NaN       0                  1000
# 1                         NaN       0                    94
# 2                         NaN   48767                   108
# 3                         NaN       0                   106
# 4                         NaN   36357                    68
# ...                       ...     ...                   ...
# 7065             23405.987980   71941                    73
# 7066              3096.511217   21604                    79
# 7067              8163.890428       0                    85
# 7068              7524.442436   21941                    96
# 7069              2611.836866       0                    77
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# ...

# %%
data['Customer Lifetime Value'] = data['Customer Lifetime Value']*100

# %%
data._get_numeric_data()
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                         NaN       0                  1000
# 1                         NaN       0                    94
# 2                         NaN   48767                   108
# 3                         NaN       0                   106
# 4                         NaN   36357                    68
# ...                       ...     ...                   ...
# 7065             2.340599e+06   71941                    73
# 7066             3.096511e+05   21604                    79
# 7067             8.163890e+05       0                    85
# 7068             7.524442e+05   21941                    96
# 7069             2.611837e+05       0                    77
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# ...

# %%
#Check for duplicate rows in the data and remove if any
data = data.drop_duplicates()

# %%
data
# Out:
#      Customer       State Gender  Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                      NaN       0
# 1     QZ44356     Arizona      F                      NaN       0
# 2     AI49188      Nevada      F                      NaN   48767
# 3     WW63253  California      M                      NaN       0
# 4     GA49547  Washington      M                      NaN   36357
# ...       ...         ...    ...                      ...     ...
# 7065      NaN  California      M             2.340599e+06   71941
# 7066      NaN  California      F             3.096511e+05   21604
# 7067      NaN  California      M             8.163890e+05       0
# 7068      NaN  California      M             7.524442e+05   21941
# 7069      NaN  California      M             2.611837e+05       0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                     1000   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Filter out the data for customers who have an income of 0 or less
data[data['Income']<=0]
# Out:
#      Customer       State Gender  Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                      NaN       0
# 1     QZ44356     Arizona      F                      NaN       0
# 3     WW63253  California      M                      NaN       0
# 7     CF85061     Arizona      M                      NaN       0
# 10    SX51350  California      M                      NaN       0
# ...       ...         ...    ...                      ...     ...
# 7059      NaN  California      F             5.678050e+05       0
# 7061      NaN  California      M             1.987226e+06       0
# 7062      NaN  California      M             4.628995e+05       0
# 7067      NaN  California      M             8.163890e+05       0
# 7069      NaN  California      M             2.611837e+05       0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                     1000   Personal Auto  Four-Door Car            2.704934
# ...
